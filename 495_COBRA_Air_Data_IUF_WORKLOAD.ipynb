# %%
# Import the necessary libraries
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import os

# %%
# first set the working directory. This code will be changed based on the relative location of the data files 
# on the local drive of the computer executing the command. 
os.chdir('C:\\Users\\belincoln\\Documents\\! CBP\\!User Fees\\!! Goal 1 Dashboards')

# Works well for Jupyter Notebooks, can be configured in Spyder using file explorer. 
collections = pd.read_excel(os.path.join('Source Emails & Source Files','Files','Collections',
                                         'COBRA_Air','Collections cc495 - FY13 - FY18.xls'))

# %%
# Begin Data Cleaning
# delete columns and rows that contain only na
collections = collections.dropna(axis=0, how = 'all')
collections = collections.dropna(axis=1, how = 'all')

# %%
# Delete the first two rows and only keep the Period Column and Collection Columns
collections = collections.iloc[2:,[1,-1,-3,-4]]

# %%
# Make first row column headers
collections.columns = collections.iloc[0,:]

# %%
# Make sure all columns have a name! Rename first column 'Period'
# Delete first two rows
collections.columns.values[0] = 'Period'

collections = collections.iloc[2:,:]

# %%
# Delete rows that contain sums for each company (don't want to double count collections)
# Also delete additional NaNs
collections = collections.dropna(axis = 0, subset = ['Period'])

# %%
# Sum Interest, Penalty, and Principal Collection Amounts
collections['Collections'] = collections[['Applied Penalty Amount', 'Applied Interest Amount',
       'Applied Principal Amount']].sum(axis = 1)

# %%
# remove tilda from index (unclear why it exists in the first place)
collections['Period'] = collections['Period'].str.rstrip('~')
# remove extra space from index
collections['Period'] = collections['Period'].str.rstrip(' ')

# %%
# Groups Collections based on Collection Period, across all companies
collections = collections.groupby(collections['Period']).sum()

# %%
# Remove audit payments
collections= collections[~collections.index.str.contains("\*")]

# Add an additional column that shows remittance period (independent of year)
collections['Remittance Period'] = collections.index.str.split('20').str[0]


# Create Calendar Year Column
collections['Calendar Year'] = collections.index.str.split(')').str[1]
# Turn Years into integers
collections['Calendar Year'] = collections['Calendar Year'].astype(int)

# Filter on years not a part of analysis
years = [2012,2013,2014,2015,2016,2017,2018]
collections = collections[collections['Calendar Year'].isin(years)]

# %%
#remove collection data for which we don't have workload data
searchfor = ['Qtr 01 \(Jan-Mar\) 2012','Qtr 02 \(Apr-Jun\) 2012', 'Qtr 03 \(Jul-Sept\) 2012','Qtr 04 \(Oct-Dec\) 2018']
collections = collections[~collections.index.str.contains('|'.join(searchfor))]

# %%
#%% Read Workload Data
workload = pd.read_excel(os.path.join('Source Emails & Source Files','Files','Workload',
                                      'COBRA_Air','FY09-fy18-passenger data air and cruise.xlsx'))

# %%
# Drop Cruise and Total Rows
workload.drop([7,8],axis = 0,inplace=True)

# %%
workload['Data Id'] = workload['Data Id'] + ': ' + workload['Data Elements  - National']

# %%
workload.drop('Data Elements  - National', axis = 1, inplace = True)

# %%
workload['Data Id'] = workload['Data Id'].shift()
workload = workload.iloc[[1,3,5]]

# %%
workload
# Out:
#                                              Data Id  10/1/2008  11/1/2008  \
# 1                  USC00011: Commercial Aircraft Pax  5437977.0  4986218.0
# 3              MPP00013: Private Aircraft Passengers    31531.0    32307.0
# 5  USCP0011: Preclear Air Ports Pax/Crew combined...        NaN        NaN
#
#    12/1/2008   1/1/2009   2/1/2009   3/1/2009   4/1/2009   5/1/2009  \
# 1  5446923.0  5628757.0  4590526.0  5649832.0  5848890.0  5324342.0
# 3    29799.0    36279.0    27772.0    33705.0    29347.0    20400.0
# 5        NaN        NaN        NaN        NaN        NaN        NaN
#
#     6/1/2009  ...  12/1/2017   1/1/2018   2/1/2018   3/1/2018   4/1/2018  \
# 1  5873692.0  ...  7794441.0  8235566.0  6785954.0  8600528.0  8662139.0
# 3    24314.0  ...    22546.0    25712.0    23464.0    30079.0    26404.0
# 5        NaN  ...  1596994.0  1565813.0  1530305.0  1884844.0  1745714.0
#
#     5/1/2018   6/1/2018    7/1/2018    8/1/2018   9/1/2018
# 1  8608627.0  9165631.0  10615039.0  10164128.0  8102772.0
# 3    22555.0    24388.0     26656.0     23076.0    20025.0
# 5  1680540.0  1845968.0   2073376.0   2034479.0  1651825.0
#
# [3 rows x 121 columns]

# %%
workload = workload.append(workload.sum(numeric_only = True), ignore_index = True)
workload = workload.transpose()

# %%
workload.iloc[0,-1] = 'Sum of Workload Ids'

# %%
workload.columns = workload.iloc[0]
workload.drop('Data Id', inplace = True, axis = 0)

# %%
# Create Calendar Year and Month Columns
workload['Month'] = workload.index.str.split('/').str[0]
workload['Calendar Year'] = workload.index.str.split('/').str[2]

# %%
# Filter on years not a part of analysis
years = ['2012','2013','2014','2015','2016','2017','2018']
workload = workload[workload['Calendar Year'].isin(years)]

# %%
# Build out Remittance Period Columns
conditions = [(workload['Month'] == '1'), (workload['Month'] == '2'), (workload['Month'] == '3'), 
              (workload['Month'] == '4'), (workload['Month'] == '5'), (workload['Month'] == '6'),
              (workload['Month'] == '7'),(workload['Month'] == '8'),(workload['Month'] == '9'),
              (workload['Month'] == '10'),(workload['Month'] == '11'),(workload['Month'] == '12')] 
choices = ['Qtr 01 (Jan-Mar)','Qtr 01 (Jan-Mar)','Qtr 01 (Jan-Mar)',
           'Qtr 02 (Apr-Jun)','Qtr 02 (Apr-Jun)','Qtr 02 (Apr-Jun)',
           'Qtr 03 (Jul-Sept)','Qtr 03 (Jul-Sept)', 'Qtr 03 (Jul-Sept)',
           'Qtr 04 (Oct-Dec)','Qtr 04 (Oct-Dec)','Qtr 04 (Oct-Dec)']
workload['Remittance Period'] = np.select(conditions, choices, default='error')

# %%
# Reset index to Remittance Period plus Calendar Year to merge with Collection data
workload.index = workload['Remittance Period'] + ' ' + workload['Calendar Year']
# Drop unnecssary columns
workload.drop(['Calendar Year', 'Month','Remittance Period'], inplace = True, axis=1)

# %%
# Sum on Remittance Period
workload = workload.groupby(workload.index).sum()

# %%
workload_collections = pd.merge(workload,collections,how = 'inner', left_index = True, right_index = True)
#%%

# %%
len(workload_collections)
# Out:
# 24

# %%
corr = workload_collections.corr()

# %%
corr
# Out:
#                                                     USC00011: Commercial Aircraft Pax  \
# USC00011: Commercial Aircraft Pax                                            1.000000
# MPP00013: Private Aircraft Passengers                                       -0.292130
# USCP0011: Preclear Air Ports Pax/Crew combined ...                           0.947597
# Sum of Workload Ids                                                          0.998886
# Collections                                                                 -0.109670
# Calendar Year                                                                0.713713
#
#                                                     MPP00013: Private Aircraft Passengers  \
# USC00011: Commercial Aircraft Pax                                               -0.292130
# MPP00013: Private Aircraft Passengers                                            1.000000
# USCP0011: Preclear Air Ports Pax/Crew combined ...                              -0.339901
# Sum of Workload Ids                                                             -0.299855
# Collections                                                                      0.370522
# Calendar Year                                                                   -0.384099
#
#                                                     USCP0011: Preclear Air Ports Pax/Crew combined (Calc)  \
# USC00011: Commercial Aircraft Pax                                                            0.947597
# MPP00013: Private Aircraft Passengers                                                       -0.339901
# USCP0011: Preclear Air Ports Pax/Crew combined ...                                           1.000000
# Sum of Workload Ids                                                                          0.961612
# Collections                                                                                 -0.052793
# Calendar Year                                                                                0.852463
#
#                                                     Sum of Workload Ids  \
# USC00011: Commercial Aircraft Pax                              0.998886
# MPP00013: Private Aircraft Passengers                         -0.299855
# USCP0011: Preclear Air Ports Pax/Crew combined ...             0.961612
# Sum of Workload Ids                                            1.000000
# Collections                                                   -0.101463
# Calendar Year                                                  0.738833
#
#                                                     Collections  Calendar Year
# USC00011: Commercial Aircraft Pax                     -0.109670       0.713713
# MPP00013: Private Aircraft Passengers                  0.370522      -0.384099
# USCP0011: Preclear Air Ports Pax/Crew combined ...    -0.052793       0.852463
# Sum of Workload Ids                                   -0.101463       0.738833
# Collections                                            1.000000       0.177910
# Calendar Year                                          0.177910       1.000000

# %%
workload_collections
# Out:
#                         USC00011: Commercial Aircraft Pax  \
# Qtr 01 (Jan-Mar) 2013                          18700855.0
# Qtr 01 (Jan-Mar) 2014                          19219847.0
# Qtr 01 (Jan-Mar) 2015                          20244415.0
# Qtr 01 (Jan-Mar) 2016                          21847254.0
# Qtr 01 (Jan-Mar) 2017                          22369440.0
# Qtr 01 (Jan-Mar) 2018                          23622048.0
# Qtr 02 (Apr-Jun) 2013                          20632109.0
# Qtr 02 (Apr-Jun) 2014                          21778636.0
# Qtr 02 (Apr-Jun) 2015                          22657474.0
# Qtr 02 (Apr-Jun) 2016                          23744750.0
# Qtr 02 (Apr-Jun) 2017                          25475349.0
# Qtr 02 (Apr-Jun) 2018                          26436397.0
# Qtr 03 (Jul-Sept) 2013                         23423229.0
# Qtr 03 (Jul-Sept) 2014                         24121281.0
# Qtr 03 (Jul-Sept) 2015                         25837861.0
# Qtr 03 (Jul-Sept) 2016                         27135524.0
# Qtr 03 (Jul-Sept) 2017                         28198779.0
# Qtr 03 (Jul-Sept) 2018                         28881939.0
# Qtr 04 (Oct-Dec) 2012                          17844664.0
# Qtr 04 (Oct-Dec) 2013                          18928933.0
# Qtr 04 (Oct-Dec) 2014                          19252823.0
# Qtr 04 (Oct-Dec) 2015                          20944324.0
# Qtr 04 (Oct-Dec) 2016                          21715743.0
# Qtr 04 (Oct-Dec) 2017                          22638899.0
#
#                         MPP00013: Private Aircraft Passengers  \
# Qtr 01 (Jan-Mar) 2013                                 83857.0
# Qtr 01 (Jan-Mar) 2014                                 83617.0
# Qtr 01 (Jan-Mar) 2015                                 83705.0
# Qtr 01 (Jan-Mar) 2016                                 84635.0
# Qtr 01 (Jan-Mar) 2017                                 77939.0
# Qtr 01 (Jan-Mar) 2018                                 79255.0
# Qtr 02 (Apr-Jun) 2013                                 81847.0
# Qtr 02 (Apr-Jun) 2014                                 84433.0
# Qtr 02 (Apr-Jun) 2015                                 82242.0
# Qtr 02 (Apr-Jun) 2016                                 80985.0
# Qtr 02 (Apr-Jun) 2017                                 79405.0
# Qtr 02 (Apr-Jun) 2018                                 73347.0
# Qtr 03 (Jul-Sept) 2013                                78574.0
# Qtr 03 (Jul-Sept) 2014                                81245.0
# Qtr 03 (Jul-Sept) 2015                                76879.0
# Qtr 03 (Jul-Sept) 2016                                80850.0
# Qtr 03 (Jul-Sept) 2017                                72326.0
# Qtr 03 (Jul-Sept) 2018                                69757.0
# Qtr 04 (Oct-Dec) 2012                                 74730.0
# Qtr 04 (Oct-Dec) 2013                                 76039.0
# Qtr 04 (Oct-Dec) 2014                                 76434.0
# Qtr 04 (Oct-Dec) 2015                                 73701.0
# Qtr 04 (Oct-Dec) 2016                                 67850.0
# Qtr 04 (Oct-Dec) 2017                                 67682.0
#
#                         USCP0011: Preclear Air Ports Pax/Crew combined (Calc)  \
# Qtr 01 (Jan-Mar) 2013                                           4006973.0
# Qtr 01 (Jan-Mar) 2014                                           4162697.0
# Qtr 01 (Jan-Mar) 2015                                           4519727.0
# Qtr 01 (Jan-Mar) 2016                                           4635919.0
# Qtr 01 (Jan-Mar) 2017                                           4762410.0
# Qtr 01 (Jan-Mar) 2018                                           4980962.0
# Qtr 02 (Apr-Jun) 2013                                           3941004.0
# Qtr 02 (Apr-Jun) 2014                                           4376274.0
# Qtr 02 (Apr-Jun) 2015                                           4615960.0
# Qtr 02 (Apr-Jun) 2016                                           4720735.0
# Qtr 02 (Apr-Jun) 2017                                           5050360.0
# Qtr 02 (Apr-Jun) 2018                                           5272222.0
# Qtr 03 (Jul-Sept) 2013                                          4329327.0
# Qtr 03 (Jul-Sept) 2014                                          4764277.0
# Qtr 03 (Jul-Sept) 2015                                          5043879.0
# Qtr 03 (Jul-Sept) 2016                                          5387849.0
# Qtr 03 (Jul-Sept) 2017                                          5618691.0
# Qtr 03 (Jul-Sept) 2018                                          5759680.0
# Qtr 04 (Oct-Dec) 2012                                           3735479.0
# Qtr 04 (Oct-Dec) 2013                                           3897774.0
# Qtr 04 (Oct-Dec) 2014                                           4264643.0
# Qtr 04 (Oct-Dec) 2015                                           4435585.0
# Qtr 04 (Oct-Dec) 2016                                           4609867.0
# Qtr 04 (Oct-Dec) 2017                                           4792383.0
#
#                         Sum of Workload Ids   Collections   Remittance Period  \
# Qtr 01 (Jan-Mar) 2013            22791685.0  1.446142e+08   Qtr 01 (Jan-Mar)
# Qtr 01 (Jan-Mar) 2014            23466161.0  1.519669e+08   Qtr 01 (Jan-Mar)
# Qtr 01 (Jan-Mar) 2015            24847847.0  1.626936e+08   Qtr 01 (Jan-Mar)
# Qtr 01 (Jan-Mar) 2016            26567808.0  1.683570e+08   Qtr 01 (Jan-Mar)
# Qtr 01 (Jan-Mar) 2017            27209789.0  1.820994e+08   Qtr 01 (Jan-Mar)
# Qtr 01 (Jan-Mar) 2018            28682265.0  1.993085e+08   Qtr 01 (Jan-Mar)
# Qtr 02 (Apr-Jun) 2013            24654960.0  1.369273e+08   Qtr 02 (Apr-Jun)
# Qtr 02 (Apr-Jun) 2014            26239343.0  1.428367e+08   Qtr 02 (Apr-Jun)
# Qtr 02 (Apr-Jun) 2015            27355676.0  1.545880e+08   Qtr 02 (Apr-Jun)
# Qtr 02 (Apr-Jun) 2016            28546470.0  1.629744e+08   Qtr 02 (Apr-Jun)
# Qtr 02 (Apr-Jun) 2017            30605114.0  1.672569e+08   Qtr 02 (Apr-Jun)
# Qtr 02 (Apr-Jun) 2018            31781966.0  1.795427e+08   Qtr 02 (Apr-Jun)
# Qtr 03 (Jul-Sept) 2013           27831130.0  1.285809e+08  Qtr 03 (Jul-Sept)
# Qtr 03 (Jul-Sept) 2014           28966803.0  1.353596e+08  Qtr 03 (Jul-Sept)
# Qtr 03 (Jul-Sept) 2015           30958619.0  1.433550e+08  Qtr 03 (Jul-Sept)
# Qtr 03 (Jul-Sept) 2016           32604223.0  1.508790e+08  Qtr 03 (Jul-Sept)
# Qtr 03 (Jul-Sept) 2017           33889796.0  1.551012e+08  Qtr 03 (Jul-Sept)
# Qtr 03 (Jul-Sept) 2018           34711376.0  7.346173e+05  Qtr 03 (Jul-Sept)
# Qtr 04 (Oct-Dec) 2012            21654873.0  1.094443e+08   Qtr 04 (Oct-Dec)
# Qtr 04 (Oct-Dec) 2013            22902746.0  1.186901e+08   Qtr 04 (Oct-Dec)
# Qtr 04 (Oct-Dec) 2014            23593900.0  1.232053e+08   Qtr 04 (Oct-Dec)
# Qtr 04 (Oct-Dec) 2015            25453610.0  1.311344e+08   Qtr 04 (Oct-Dec)
# Qtr 04 (Oct-Dec) 2016            26393460.0  1.425185e+08   Qtr 04 (Oct-Dec)
# Qtr 04 (Oct-Dec) 2017            27498964.0  1.495354e+08   Qtr 04 (Oct-Dec)
#
#                         Calendar Year
# Qtr 01 (Jan-Mar) 2013            2013
# Qtr 01 (Jan-Mar) 2014            2014
# Qtr 01 (Jan-Mar) 2015            2015
# Qtr 01 (Jan-Mar) 2016            2016
# Qtr 01 (Jan-Mar) 2017            2017
# Qtr 01 (Jan-Mar) 2018            2018
# Qtr 02 (Apr-Jun) 2013            2013
# Qtr 02 (Apr-Jun) 2014            2014
# Qtr 02 (Apr-Jun) 2015            2015
# Qtr 02 (Apr-Jun) 2016            2016
# Qtr 02 (Apr-Jun) 2017            2017
# Qtr 02 (Apr-Jun) 2018            2018
# Qtr 03 (Jul-Sept) 2013           2013
# Qtr 03 (Jul-Sept) 2014           2014
# Qtr 03 (Jul-Sept) 2015           2015
# Qtr 03 (Jul-Sept) 2016           2016
# Qtr 03 (Jul-Sept) 2017           2017
# Qtr 03 (Jul-Sept) 2018           2018
# Qtr 04 (Oct-Dec) 2012            2012
# Qtr 04 (Oct-Dec) 2013            2013
# Qtr 04 (Oct-Dec) 2014            2014
# Qtr 04 (Oct-Dec) 2015            2015
# Qtr 04 (Oct-Dec) 2016            2016
# Qtr 04 (Oct-Dec) 2017            2017

# %%
# %store workload_collections
# Out:
# Stored 'workload_collections' (DataFrame)
